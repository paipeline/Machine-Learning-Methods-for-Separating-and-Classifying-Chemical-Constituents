# %% [markdown]
# ## Model performance with:
# 1. different window_sizes = [1, 5, 10, 20, 30, 40, 50, 100, 200]
# 2. with or without baseline removal
# 3. Cut data points from 2500 -x

# %% [markdown]
# # Contrast before and after smoothing
